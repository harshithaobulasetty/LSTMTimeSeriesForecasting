# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ITC.csv')
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2019-05-29  288.799988  291.700012  287.600006  288.100006  239.825165
# 1     2019-05-30  289.000000  291.049988  288.299988  288.649994  240.282959
# 2     2019-05-31  289.350006  291.500000  277.450012  278.549988  231.875366
# 3     2019-06-03  281.399994  281.500000  275.299988  278.549988  231.875366
# 4     2019-06-04  279.250000  282.149994  278.799988  279.250000  232.458038
# ...          ...         ...         ...         ...         ...         ...
# 1231  2024-05-23  441.399994  444.899994  436.549988  441.350006  441.350006
# 1232  2024-05-24  441.000000  442.450012  435.299988  436.200012  436.200012
# 1233  2024-05-27  438.799988  438.899994  430.700012  431.500000  431.500000
# 1234  2024-05-28  432.100006  432.500000  428.250000  429.000000  429.000000
# 1235  2024-05-29  425.500000  432.399994  425.500000  430.950012  430.950012
#
#         Volume
# 0      7255516
# 1      8656311
# 2     26281811
# 3     19569620
# 4     13850737
# ...        ...
# 1231  26234369
# 1232  12761457
# 1233  11827050
# 1234   9310198
# 1235  10428062
#
# [1236 rows x 7 columns]

# %%
# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(data['Date'], data['Open'], marker='o')

# Add titles and labels
plt.title('Open Value Over Time')
plt.xlabel('Date')
plt.ylabel('Open Value')

# Improve the date formatting on the x-axis
plt.gcf().autofmt_xdate()

# Show the plot
plt.show()
